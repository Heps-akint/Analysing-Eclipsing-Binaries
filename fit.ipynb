# %%
# %pylab notebook

from astropy.table import Table
fit = Table.read('fit.out.8',format='ascii')
fit2 = Table.read('fit.out.9',format='ascii')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fit
# Out:
# <Table length=1000>
#   N    ITER      J          rA+rB     ...    loggB        rho_A        rho_B
# int64 int64   float64      float64    ...   float64      float64      float64
# ----- ----- ------------ ------------ ... ------------ ------------ ------------
#     1    36 0.9107852358 0.2412808258 ...  4.567590321  1.474905271 1.8547986254
#     2    30 0.9108240063 0.2412858282 ... 4.5699600542 1.4642302427 1.8696794395
#     3    26  0.908425867 0.2414579256 ... 4.5571577561 1.5228728318 1.7842388557
#     4    18  0.909514892 0.2414545317 ... 4.5602072272 1.5102417336 1.8001964957
#     5    20 0.9099521665 0.2414204927 ... 4.5651937682 1.4850979293 1.8350620077
#     6    34 0.9091102037 0.2414198065 ... 4.5621744206 1.4999288368 1.8153492494
#     7    32 0.9093510576 0.2413034355 ... 4.5606539748 1.5185392654 1.7964910947
#     8    28 0.9107579542 0.2415319851 ... 4.5680439628 1.4661216033 1.8552663574
# ...

# %%
fit2
# Out:
# <Table length=2499>
#   N    ITER      J          rA+rB     ...    b_pri        b_sec        Rchi2
# int64 int64   float64      float64    ...   float64      float64      float64
# ----- ----- ------------ ------------ ... ------------ ------------ ------------
#     1    26 0.9060754334 0.2402909599 ... 0.3543688515 0.3543688515 2.1883833535
#     2    28 0.9047480116 0.2394054936 ... 0.3457432303 0.3457432303 2.0755252917
#     3    28 0.9035752843 0.2392392894 ... 0.3460649075 0.3460649075 2.0098291053
#     4    34 0.9030646398 0.2395502626 ... 0.3484541394 0.3484541394 1.9906234326
#     5    24 0.9035524498 0.2399672948 ... 0.3477369915 0.3477369915 1.9979791229
#     6    38 0.9028816561 0.2402454491 ... 0.3557378438 0.3557378438 2.0114875429
#     7    28 0.9022683745 0.2404214078 ... 0.3641904561 0.3641904561 2.0258385828
#     8    26 0.9022803905 0.2402140956 ...  0.370950555  0.370950555 2.0391820014
# ...

# %%
plot(fit['r_A'],fit['r_B'],'.',label = 'Task8', color = 'red')
plot(fit2['r_A'],fit2['r_B'],'.',label = 'Task9', color = 'blue')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
