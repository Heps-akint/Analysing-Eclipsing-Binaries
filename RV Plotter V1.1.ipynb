# %%
# %pylab notebook
from astropy.table import Table
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tb1 = Table.read('1.rv.out.3',format='ascii')
tb1
# Out:
# <Table length=18>
#     TIME    RV_STAR_A  ERROR    PHASE      MODEL     (O-C)
#   float64    float64  float64  float64    float64   float64
# ----------- --------- ------- ---------- ---------- --------
#  1293.76553   -125.24    0.97 0.24148555 -126.02421  0.78421
#  942.710533     -72.3     1.3 0.07108717  -74.63161  2.33161
#  935.778639      27.8     1.0 0.88863392   22.95877  4.84123
#  909.867888     -38.8     1.2 0.99293069  -31.42618 -7.37382
#  879.922449    -124.5     1.0 0.24489014 -126.10722  1.60722
#  502.975883    -117.9     1.1 0.18759505 -119.27052  1.37052
#  501.968965     53.45     1.0 0.72531598   54.15816 -0.70816
# 1384.590236      -1.4     1.3 0.93937954   -1.73601  0.33601
# 1292.778371     52.51    0.94 0.78827791   52.63624 -0.12624
# 1217.992487     -58.8     5.5 0.45385504   -61.3841   2.5841
# 1028.586381     -38.4     2.4 0.49694566  -37.19409 -1.20591
# 1541.009679     54.56    0.98 0.75201334   55.23958 -0.67958
# ...

# %%
tb2 = Table.read('2.rv.out.3',format='ascii')
tb2
# Out:
# <Table length=18>
#     TIME    RV_STAR_A  ERROR    PHASE      MODEL     (O-C)
#   float64    float64  float64  float64    float64   float64
# ----------- --------- ------- ---------- ---------- --------
#  1293.76553      83.3     1.0 0.24148555   81.00872  2.29128
#  942.710533      12.1     1.6 0.07108717    14.6227  -2.5227
#  935.778639    -114.0     1.2 0.88863392   -111.439   -2.561
#  909.867888     -38.8     1.2 0.99293069  -41.18762  2.38762
#  879.922449      81.2     1.1 0.24489014   81.11596  0.08404
#  502.975883      71.2     1.2 0.18759505    72.2847  -1.0847
#  501.968965    -150.1     1.7 0.72531598  -151.7406   1.6406
# 1384.590236     -82.0     1.2 0.93937954  -79.53969 -2.46031
# 1292.778371    -147.9     1.5 0.78827791 -149.77467  1.87467
# 1217.992487      -5.4     6.6 0.45385504   -2.48968 -2.91032
# 1028.586381     -38.4     2.4 0.49694566  -33.73697 -4.66303
# 1541.009679    -149.4     1.4 0.75201334 -153.13752  3.73752
# ...

# %%
RV1_err = tb1['ERROR']
RV2_err = tb2['ERROR']
RV1 = tb1['RV_STAR_A']
RV2 = tb2['RV_STAR_A']
PHASE1 = tb1['PHASE']
PHASE2 = tb2['PHASE']
resid1 = tb1['(O-C)']
resid2 = tb2['(O-C)']

# %%
tbmod = Table.read('mod.r.out.3',format='ascii')
tbmod
# Out:
# <Table length=10001>
#  PHASE  MAGNITUDE    L1      L2      L3   UNINTMAG   RV_A     RV_B
# float64  float64  float64 float64 float64 float64  float64  float64
# ------- --------- ------- ------- ------- -------- -------- --------
#     0.0  0.541863 0.73686  0.2602     0.0 0.541863 -35.4536 -35.9853
#  0.0001  0.541848 0.73686  0.2602     0.0 0.541848 -35.5106 -35.9117
#  0.0002  0.541804 0.73686  0.2602     0.0 0.541804 -35.5675  -35.838
#  0.0003  0.541729 0.73686  0.2602     0.0 0.541729 -35.6245 -35.7644
#  0.0004  0.541625 0.73686  0.2602     0.0 0.541625 -35.6815 -35.6908
#  0.0005  0.541492 0.73686  0.2602     0.0 0.541492 -35.7385 -35.6172
#  0.0006  0.541328 0.73686  0.2602     0.0 0.541328 -35.7955 -35.5436
#  0.0007  0.541135 0.73686  0.2602     0.0 0.541135 -35.8525   -35.47
#  0.0008  0.540913 0.73686  0.2602     0.0 0.540913 -35.9095 -35.3964
#  0.0009  0.540661 0.73686  0.2602     0.0 0.540661 -35.9665 -35.3227
# ...

# %%
RVmod1 = tbmod['RV_A']
PHmod = tbmod['PHASE']
RVmod2 = tbmod['RV_B']

fig, axs = plt.subplots(2,sharex=True)
axs[0].plot(PHmod,RVmod1,c='r')
axs[0].plot(PHmod,RVmod2,c='b')
axs[0].errorbar(PHASE1,RV1,yerr=RV1_err,c='r',fmt='o')
axs[0].errorbar(PHASE2,RV2,yerr=RV2_err,c='b',fmt='o')
fig.suptitle('Radial Velocity plot')
axs[1].set_xlabel('Phase')
axs[0].set_ylabel('Radial Velocity (km/s)')
axs[1].set_ylabel('Residuals')
axs[1].scatter(PHASE1,resid1,c='r')
axs[1].scatter(PHASE2,resid2,c='b')
fig.show()
fig.savefig('Radial Velocity plot.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
